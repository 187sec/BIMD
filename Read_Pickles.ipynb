# %%
import pickle
import pandas
# Out:
# /home/jbai/anaconda3/envs/business/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /home/jbai/anaconda3/envs/business/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
df = pandas.read_pickle("10-K_for_snp500.pkl")

# %%
df
# Out:
#                       0        1   2  \
# 0            3M Company    66740   0
# 1            3M Company    66740   1
# 2            3M Company    66740   2
# 3            3M Company    66740   3
# 4            3M Company    66740   4
# 5            3M Company    66740   5
# 6            3M Company    66740   6
# 7            3M Company    66740   7
# 8            3M Company    66740   8
# 9            3M Company    66740   9
# 10           3M Company    66740  10
# 11           3M Company    66740  11
# 12           3M Company    66740  12
# 13  Abbott Laboratories     1800   0
# 14  Abbott Laboratories     1800   1
# 15  Abbott Laboratories     1800   2
# 16  Abbott Laboratories     1800   3
# 17  Abbott Laboratories     1800   4
# 18  Abbott Laboratories     1800   5
# 19  Abbott Laboratories     1800   6
# 20  Abbott Laboratories     1800   7
# 21  Abbott Laboratories     1800   8
# 22  Abbott Laboratories     1800   9
# 23  Abbott Laboratories     1800  10
# ...
